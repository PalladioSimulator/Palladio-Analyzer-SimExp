# %%
import pandas as pd
from pathlib import Path
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.set_theme()

# %%
simexp_path = Path.cwd().parent / "simulation_result"

# %%
df = pd.read_csv(simexp_path / "resources" / "DeltaIoT_modelled_ea_strategy1c_pareto_front_rank.csv")

# %%
df.head()
# Out:
#    generation         hv  hv rank
# 0           1  83.736271       20
# 1           2  83.754361       21
# 2           3  82.341861        8
# 3           4  84.642917       26
# 4           5  83.314797       15

# %%
sns.lineplot(data=df, x="generation", y="hv", marker="o")
plt.show()
